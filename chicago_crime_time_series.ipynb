# %% [markdown]
# <a href="https://colab.research.google.com/github/Qteit/chicago-crime-time-series/blob/main/chicago_crime_time_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # core 1

# %%
import pandas as pd

# %%
csv_files = ['/content/drive/MyDrive/Data/Chicago-Crime_2001.csv','/content/drive/MyDrive/Data/Chicago-Crime_2002.csv','/content/drive/MyDrive/Data/Chicago-Crime_2003.csv',
             '/content/drive/MyDrive/Data/Chicago-Crime_2004.csv','/content/drive/MyDrive/Data/Chicago-Crime_2005.csv','/content/drive/MyDrive/Data/Chicago-Crime_2006.csv',
             '/content/drive/MyDrive/Data/Chicago-Crime_2007.csv','/content/drive/MyDrive/Data/Chicago-Crime_2008.csv','/content/drive/MyDrive/Data/Chicago-Crime_2009.csv',
             '/content/drive/MyDrive/Data/Chicago-Crime_2010.csv','/content/drive/MyDrive/Data/Chicago-Crime_2011.csv','/content/drive/MyDrive/Data/Chicago-Crime_2012.csv',
             '/content/drive/MyDrive/Data/Chicago-Crime_2013.csv','/content/drive/MyDrive/Data/Chicago-Crime_2014.csv','/content/drive/MyDrive/Data/Chicago-Crime_2015.csv',
             '/content/drive/MyDrive/Data/Chicago-Crime_2016.csv','/content/drive/MyDrive/Data/Chicago-Crime_2017.csv','/content/drive/MyDrive/Data/Chicago-Crime_2018.csv',
             '/content/drive/MyDrive/Data/Chicago-Crime_2019.csv','/content/drive/MyDrive/Data/Chicago-Crime_2020.csv','/content/drive/MyDrive/Data/Chicago-Crime_2021.csv',
             '/content/drive/MyDrive/Data/Chicago-Crime_2022.csv']

# %%
dataframes = [pd.read_csv(file) for file in csv_files]
df = pd.concat(dataframes, ignore_index=True)

# %%
df
# Out:
#                ID                    Date        Primary Type  \
# 0         1326041  01/01/2001 01:00:00 AM             BATTERY
# 1         1319931  01/01/2001 01:00:00 PM             BATTERY
# 2         1324743  01/01/2001 01:00:00 PM            GAMBLING
# 3         1310717  01/01/2001 01:00:00 AM     CRIMINAL DAMAGE
# 4         1318099  01/01/2001 01:00:00 AM             BATTERY
# ...           ...                     ...                 ...
# 7713104  12938029  12/31/2022 12:50:00 PM             ASSAULT
# 7713105  12937822  12/31/2022 12:50:00 PM             ASSAULT
# 7713106  12937583  12/31/2022 12:52:00 AM             BATTERY
# 7713107  12938420  12/31/2022 12:52:00 PM             ASSAULT
# 7713108  12939906  12/31/2022 12:59:00 PM  DECEPTIVE PRACTICE
#
#                                      Description  \
# 0                                         SIMPLE
# 1                                         SIMPLE
# 2                            ILLEGAL ILL LOTTERY
# ...

# %%
df['Primary Type'].value_counts()
# Out:
# Primary Type
# THEFT                                1626992
# BATTERY                              1410889
# CRIMINAL DAMAGE                       878914
# NARCOTICS                             746155
# ASSAULT                               501103
# OTHER OFFENSE                         479174
# BURGLARY                              422246
# MOTOR VEHICLE THEFT                   366586
# DECEPTIVE PRACTICE                    340958
# ROBBERY                               289677
# CRIMINAL TRESPASS                     212869
# WEAPONS VIOLATION                     103906
# PROSTITUTION                           69750
# OFFENSE INVOLVING CHILDREN             55280
# PUBLIC PEACE VIOLATION                 52086
# SEX OFFENSE                            30442
# CRIM SEXUAL ASSAULT                    27584
# INTERFERENCE WITH PUBLIC OFFICER       18206
# LIQUOR LAW VIOLATION                   14846
# GAMBLING                               14616
# ...

# %% [markdown]
# # Topic 1) Comparing Police Districts

# %% [markdown]
# ## Which district had the most crimes in 2022?

# %%
df['District'].value_counts()
# Out:
# District
# 8.0     518549
# 11.0    495947
# 6.0     450645
# 7.0     447273
# 25.0    439160
# 4.0     437746
# 3.0     391059
# 12.0    381247
# 9.0     377311
# 2.0     364725
# 19.0    345934
# 18.0    345666
# 5.0     342118
# 10.0    332395
# 15.0    331469
# 1.0     310778
# 14.0    298794
# 16.0    257949
# 22.0    252722
# 24.0    232700
# 17.0    222523
# 20.0    136112
# 31.0       236
# 21.0         4
# Name: count, dtype: int64

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7713109 entries, 0 to 7713108
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Date                  datetime64[ns]
#  2   Primary Type          object
#  3   Description           object
#  4   Location Description  object
#  5   Arrest                bool
#  6   Domestic              bool
#  7   Beat                  int64
#  8   District              float64
#  9   Ward                  float64
#  10  Latitude              float64
#  11  Longitude             float64
# dtypes: bool(2), datetime64[ns](1), float64(4), int64(2), object(3)
# memory usage: 603.2+ MB

# %%
df=df.set_index(df['Date'])

# %%
df.head()
# Out:
#                           ID                Date     Primary Type  \
# Date
# 2001-01-01 01:00:00  1326041 2001-01-01 01:00:00          BATTERY
# 2001-01-01 13:00:00  1319931 2001-01-01 13:00:00          BATTERY
# 2001-01-01 13:00:00  1324743 2001-01-01 13:00:00         GAMBLING
# 2001-01-01 01:00:00  1310717 2001-01-01 01:00:00  CRIMINAL DAMAGE
# 2001-01-01 01:00:00  1318099 2001-01-01 01:00:00          BATTERY
#
#                              Description     Location Description  Arrest  \
# Date
# 2001-01-01 01:00:00               SIMPLE                RESIDENCE   False
# 2001-01-01 13:00:00               SIMPLE                RESIDENCE   False
# 2001-01-01 13:00:00  ILLEGAL ILL LOTTERY                   STREET    True
# 2001-01-01 01:00:00           TO VEHICLE                   STREET   False
# 2001-01-01 01:00:00               SIMPLE  RESIDENCE PORCH/HALLWAY   False
#
#                      Domestic  Beat  District  Ward   Latitude  Longitude
# Date
# ...

# %%
df_dis_2022=df.loc['2022']
df_dis_2022
# Out:
#                            ID                Date        Primary Type  \
# Date
# 2022-01-01 13:00:00  12582293 2022-01-01 13:00:00               THEFT
# 2022-01-01 13:00:00  12607313 2022-01-01 13:00:00  DECEPTIVE PRACTICE
# 2022-01-01 01:00:00  12585671 2022-01-01 01:00:00     CRIMINAL DAMAGE
# 2022-01-01 01:00:00  12592889 2022-01-01 01:00:00       OTHER OFFENSE
# 2022-01-01 01:00:00  12584977 2022-01-01 01:00:00               THEFT
# ...                       ...                 ...                 ...
# 2022-12-31 12:50:00  12938029 2022-12-31 12:50:00             ASSAULT
# 2022-12-31 12:50:00  12937822 2022-12-31 12:50:00             ASSAULT
# 2022-12-31 00:52:00  12937583 2022-12-31 00:52:00             BATTERY
# 2022-12-31 12:52:00  12938420 2022-12-31 12:52:00             ASSAULT
# 2022-12-31 12:59:00  12939906 2022-12-31 12:59:00  DECEPTIVE PRACTICE
#
#                                                  Description  \
# Date
# ...

# %%
# df_dis_2022['District'].value_counts(ascending=False) / give me district with highest value
# df_dis_2022['District'].value_counts(ascending=True) give me district with least value

# %%
crimes_district = df_dis_2022.groupby('District').size()
crimes_district
# Out:
# District
# 1.0     13044
# 2.0     11793
# 3.0     11937
# 4.0     13931
# 5.0      9773
# 6.0     14694
# 7.0     10319
# 8.0     14805
# 9.0     10376
# 10.0     9961
# 11.0    13457
# 12.0    14341
# 14.0     8158
# 15.0     8308
# 16.0     9226
# 17.0     6997
# 18.0    12429
# 19.0    12243
# 20.0     4960
# 22.0     7671
# 24.0     8469
# 25.0    11951
# 31.0       15
# dtype: int64

# %%
most_crime_district = crimes_district.idxmax()
most_crime_count = crimes_district.max()
print(most_crime_district)
print(most_crime_count)
# Out:
# 8.0
# 14805

# %% [markdown]
# ## Which had the least?

# %%
least_crime_district = crimes_district.idxmin()
least_crime_count = crimes_district.min()
print(least_crime_district)
print(least_crime_count)
# Out:
# 31.0
# 15

# %%
df_dis_arrest_2022_True = df_dis_2022[df_dis_2022['Arrest'] == True].groupby('District').size()
df_dis_arrest_2022_True
# Out:
# District
# 1.0     1647
# 2.0     1049
# 3.0     1087
# 4.0     1299
# 5.0     1260
# 6.0     1584
# 7.0     1222
# 8.0     1389
# 9.0     1126
# 10.0    1688
# 11.0    3097
# 12.0    1174
# 14.0     836
# 15.0    1277
# 16.0    1247
# 17.0     750
# 18.0    1457
# 19.0     921
# 20.0     451
# 22.0     769
# 24.0     844
# 25.0    1547
# 31.0       9
# dtype: int64

# %%
df_dis_Domestic_2022_False = df_dis_2022[df_dis_2022['Domestic'] == False].groupby('District').size()
df_dis_Domestic_2022_False
# Out:
# District
# 1.0     12139
# 2.0      9390
# 3.0      8856
# 4.0     10331
# 5.0      7140
# 6.0     10812
# 7.0      7342
# 8.0     11726
# 9.0      8339
# 10.0     7554
# 11.0    10417
# 12.0    12811
# 14.0     7247
# 15.0     6099
# 16.0     7773
# 17.0     5957
# 18.0    11666
# 19.0    11261
# 20.0     4385
# 22.0     6093
# 24.0     7167
# 25.0     9489
# 31.0       15
# dtype: int64

# %%
df_dis_Domestic_2022_True = df_dis_2022[df_dis_2022['Domestic'] == True].groupby('District').size()
df_dis_Domestic_2022_True
# Out:
# District
# 1.0      905
# 2.0     2403
# 3.0     3081
# 4.0     3600
# 5.0     2633
# 6.0     3882
# 7.0     2977
# 8.0     3079
# 9.0     2037
# 10.0    2407
# 11.0    3040
# 12.0    1530
# 14.0     911
# 15.0    2209
# 16.0    1453
# 17.0    1040
# 18.0     763
# 19.0     982
# 20.0     575
# 22.0    1578
# 24.0    1302
# 25.0    2462
# dtype: int64

# %% [markdown]
# ## Analysis

# %% [markdown]
# * After organized the data then filtter this dataset for just appper the data at crime at 2022 i find the district most crime it's happen in  district (8.0) with (14,805) crime , this huge number make us think that this distinct is a chaotic and unlivable place, but when we look at the arrests that occurred, we discover that their number reached
# (1,389) and the number of crimes in which no one was arrested reached (13,416), this explains that (90.6%) of these crimes were minor incidents or not of great importance, and this shows that the area is not in great chaos , on other hand i look about 'Domestic' i find about (3,079) resulting from internal family issues and (11,726) Not due to internal family issues this huge number with (79.2%) but still the cases that have not been arrests this mean this area don't live in chaos and
# insecurity from 1-1-2022 to 31-12-2022 .
#
# * then loc for the ditrict least crime it's happen in district (31.0) with (15) crime , which that make this district safest district in the city of Chicago from the first look but actually that doesn't true when we look the crime domestic we find all of the (15) are not demostic that mean (100 %), which that make this crimes more dangerous, amd when we look at cases of arrest we find that (9) cases that mean (60%) so more than half of this crime is dangerous from 1-1-2022 to 31-12-2022 .
#
#
#
# *   In conclusion, District 8 has the highest crime rate for the year 2022, but as we explained, the arrest rate did not exceed 9.4%, which is a very small percentage considering the area of ​​this area and the number of residents living in it, but I cannot confirm this (area and number of residents) due to the lack of information available to me. Compared to District 31, it had the lowest crime rate in the area, but the arrest rate reached 60%, which is a high percentage. In addition, the problems were not 100% familial, which increases the risk level.

# %% [markdown]
# # Topic 2) Crimes Across the Years:

# %% [markdown]
# ## Is the total number of crimes increasing or decreasing across the years?

# %%
ts = df['ID'].copy()
ts.index
# Out:
# DatetimeIndex(['2001-01-01 01:00:00', '2001-01-01 13:00:00',
#                '2001-01-01 13:00:00', '2001-01-01 01:00:00',
#                '2001-01-01 01:00:00', '2001-01-01 01:00:00',
#                '2001-01-01 01:00:00', '2001-01-01 01:00:00',
#                '2001-01-01 01:00:00', '2001-01-01 01:00:00',
#                ...
#                '2022-12-31 12:41:00', '2022-12-31 00:42:00',
#                '2022-12-31 00:44:00', '2022-12-31 00:45:00',
#                '2022-12-31 12:45:00', '2022-12-31 12:50:00',
#                '2022-12-31 12:50:00', '2022-12-31 00:52:00',
#                '2022-12-31 12:52:00', '2022-12-31 12:59:00'],
#               dtype='datetime64[ns]', name='Date', length=7713109, freq=None)

# %%
crime_year= ts.resample('Y').size()
crime_year
# Out:
# <ipython-input-21-2586140af0c9>:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   crime_year= ts.resample('Y').size()
# Date
# 2001-12-31    485886
# 2002-12-31    486807
# 2003-12-31    475985
# 2004-12-31    469422
# 2005-12-31    453773
# 2006-12-31    448179
# 2007-12-31    437087
# 2008-12-31    427183
# 2009-12-31    392827
# 2010-12-31    370513
# 2011-12-31    351993
# 2012-12-31    336319
# 2013-12-31    307536
# 2014-12-31    275789
# 2015-12-31    264787
# 2016-12-31    269823
# 2017-12-31    269100
# 2018-12-31    268899
# 2019-12-31    261325
# 2020-12-31    212194
# 2021-12-31    208824
# 2022-12-31    238858
# Freq: YE-DEC, Name: ID, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
fig, ax = plt.subplots(figsize=(12, 3))

# Plot the data
ax.plot(crime_year)

# Set the title and labels
ax.set_title('Chicago Crime from 2001-2022')
ax.set_ylabel('Number of Crimes')

# Customize x-axis ticks
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Customize minor x-axis ticks
ax.xaxis.set_minor_locator(mdates.MonthLocator(interval=3))
fig.autofmt_xdate(rotation=90)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## Are there any individual crimes that are doing the opposite (e.g., decreasing when overall crime is increasing or vice-versa)?

# %%
crime_type_counts = df.groupby([df.index ,'Primary Type'])['ID'].count().unstack(fill_value=0)
crime_type_trends = crime_type_counts.resample('Y').sum()
# Out:
# <ipython-input-24-dbfbbda79e8b>:2: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   crime_type_trends = crime_type_counts.resample('Y').sum()

# %%
crime_type_trends
# Out:
# Primary Type  ARSON  ASSAULT  BATTERY  BURGLARY  \
# Date
# 2001-12-31     1011    31384    93461     26014
# 2002-12-31     1032    31523    94153     25623
# 2003-12-31      955    29477    88380     25157
# 2004-12-31      778    28850    87136     24564
# 2005-12-31      691    27067    83964     25503
# 2006-12-31      726    25945    80666     24324
# 2007-12-31      712    26313    79593     24858
# 2008-12-31      644    25448    75930     26218
# 2009-12-31      616    22861    68460     26767
# 2010-12-31      522    21537    65401     26422
# 2011-12-31      504    20411    60459     26620
# 2012-12-31      469    19900    59134     22845
# 2013-12-31      364    17972    54006     17895
# 2014-12-31      397    16903    49453     14569
# 2015-12-31      453    17048    48923     13184
# 2016-12-31      516    18742    50300     14289
# 2017-12-31      444    19306    49239     13001
# 2018-12-31      373    20406    49828     11747
# ...

# %%
overall_trend = crime_type_trends.sum(axis=1)

print(overall_trend)
# Out:
# Date
# 2001-12-31    485886
# 2002-12-31    486807
# 2003-12-31    475985
# 2004-12-31    469422
# 2005-12-31    453773
# 2006-12-31    448179
# 2007-12-31    437087
# 2008-12-31    427183
# 2009-12-31    392827
# 2010-12-31    370513
# 2011-12-31    351993
# 2012-12-31    336319
# 2013-12-31    307536
# 2014-12-31    275789
# 2015-12-31    264787
# 2016-12-31    269823
# 2017-12-31    269100
# 2018-12-31    268899
# 2019-12-31    261325
# 2020-12-31    212194
# 2021-12-31    208824
# 2022-12-31    238858
# Freq: YE-DEC, dtype: int64

# %%
overall_diff = overall_trend.diff()
crime_diff = crime_type_trends.diff()

opposite_trends = []
for crime_type in crime_type_trends.columns:
    if (overall_diff * crime_diff[crime_type]).sum() < 0:
        opposite_trends.append(crime_type)

print("Crime types with trends opposite to overall trend:")
print(opposite_trends)
# Out:
# Crime types with trends opposite to overall trend:
# ['ARSON', 'CRIMINAL SEXUAL ASSAULT', 'DECEPTIVE PRACTICE', 'DOMESTIC VIOLENCE', 'HOMICIDE', 'NON - CRIMINAL', 'OBSCENITY', 'RITUALISM', 'WEAPONS VIOLATION']

# %%
plt.figure(figsize=(12, 6))
plt.plot(overall_trend.index, overall_trend.values, label='Overall Crimes', color='black', linewidth=2)

for crime_type in opposite_trends:
    plt.plot(crime_type_trends.index, crime_type_trends[crime_type], label=crime_type, linestyle='--')

plt.title('Overall Crime Trend vs Opposite Trends (2001-2022)', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.legend(loc='upper right', fontsize=10, ncol=2)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis

# %% [markdown]
# * After analyzing the data, it became clear that crime in Chicago took a downward curve in terms of the number of crimes, as crimes gradually decreased over time, not all at once, but in several stages over the years, as the number of crimes in (2001) was (485,886), reaching
# (238,858) in (2022). This does not mean that it did not increase in years over the years before it, but the increase was very small, as it did not exceed a percentage of (0.3%) increase over the value that preceded it, so over the years crimes decreased.
#
# * In addition, it was noted that there is a number of crimes that increase or decrease inversely, as it was found that after the number of crimes increases, the number of these crimes decreases and vice versa, and the crimes are as follows:
# 1. ARSON
# 2. CRIMINAL SEXUAL ASSAULT
# 3. DECEPTIVE PRACTICE
# 4. DOMESTIC VIOLENCE
# 5. HOMICIDE
# 6. NON - CRIMINAL
# 7. OBSCENITY
# 8. RITUALISM
# 9. WEAPONS VIOLATION

# %% [markdown]
# # Topic 3) Comparing AM vs. PM Rush Hour:

# %% [markdown]
# ## Are crimes more common during AM rush hour or PM rush hour?

# %%
crime_hourly_counts = df.groupby(df.index )['ID'].count()
crime_hourly_res = crime_hourly_counts.resample('H').sum()
# Out:
# <ipython-input-29-cdd11941eff7>:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   crime_hourly_res = crime_hourly_counts.resample('H').sum()

# %%
crime_hourly_res
# Out:
# Date
# 2001-01-01 00:00:00    418
# 2001-01-01 01:00:00     91
# 2001-01-01 02:00:00     78
# 2001-01-01 03:00:00     71
# 2001-01-01 04:00:00     53
#                       ...
# 2022-12-31 19:00:00     28
# 2022-12-31 20:00:00     41
# 2022-12-31 21:00:00     42
# 2022-12-31 22:00:00     30
# 2022-12-31 23:00:00     48
# Freq: h, Name: ID, Length: 192840, dtype: int64

# %%
am_rush_hour = crime_hourly_res.between_time('07:00', '10:00')
pm_rush_hours = crime_hourly_res.between_time('16:00', '19:00')

# %%
am_count = am_rush_hour.sum()
pm_count = pm_rush_hours.sum()

# Display the results
print(f"Crimes during AM rush hour (7 AM - 10 AM): {am_count}")
print(f"Crimes during PM rush hour (4 PM - 7 PM): {pm_count}")
# Out:
# Crimes during AM rush hour (7 AM - 10 AM): 1097647
# Crimes during PM rush hour (4 PM - 7 PM): 1641051

# %%
## (19.8%)diff

# %% [markdown]
# ## What are the top 5 most common crimes during AM rush hour? What are the top 5 most common crimes during PM rush hour?

# %%
am_rush_hour = df.between_time('07:00', '10:00')
am_crime_counts = am_rush_hour.groupby('Primary Type').size().sort_values(ascending=False).head(5)

# %%
print(f'the top 5 most common crimes during AM rush hour {am_crime_counts}')
# Out:
# the top 5 most common crimes during AM rush hour Primary Type
# THEFT              220879
# BATTERY            118612
# CRIMINAL DAMAGE     93153
# BURGLARY            84944
# OTHER OFFENSE       73991
# dtype: int64

# %%
pm_rush_hour = df.between_time('16:00', '19:00')
pm_crime_counts = pm_rush_hour.groupby('Primary Type').size().sort_values(ascending=False).head(5)

# %%
print(f'the top 5 most common crimes during PM rush hour {pm_crime_counts}')
# Out:
# the top 5 most common crimes during PM rush hour Primary Type
# THEFT              333344
# BATTERY            228265
# CRIMINAL DAMAGE    155030
# NARCOTICS          107795
# ASSAULT             95933
# dtype: int64

# %% [markdown]
# ## Are Motor Vehicle Thefts more common during AM rush hour or PM Rush Hour?

# %%
am_rush_hour = df.between_time('07:00', '10:00')

pm_rush_hour = df.between_time('16:00', '19:00')

am_motor_vehicle_thefts = am_rush_hour[am_rush_hour['Primary Type'] == 'MOTOR VEHICLE THEFT']
pm_motor_vehicle_thefts = pm_rush_hour[pm_rush_hour['Primary Type'] == 'MOTOR VEHICLE THEFT']

am_count = am_motor_vehicle_thefts.shape[0]
pm_count = pm_motor_vehicle_thefts.shape[0]

print(f"Motor Vehicle Thefts during AM rush hour (7 AM - 10 AM): {am_count} crimes")
print(f"Motor Vehicle Thefts during PM rush hour (4 PM - 7 PM): {pm_count} crimes")

if am_count > pm_count:
    print("Motor Vehicle Thefts are more common during AM rush hour.")
else:
    print("Motor Vehicle Thefts are more common during PM rush hour.")
# Out:
# Motor Vehicle Thefts during AM rush hour (7 AM - 10 AM): 48764 crimes
# Motor Vehicle Thefts during PM rush hour (4 PM - 7 PM): 66116 crimes
# Motor Vehicle Thefts are more common during PM rush hour.

# %% [markdown]
# ## Analysis

# %% [markdown]
# After analyzing the crime data, it was found that the total number of crimes committed during the morning rush hour (between 7:00 AM and 10:00 AM) amounted to (1,097,647). In comparison, the total number of crimes committed during the evening rush hour (between 4:00 PM and 7:00 PM) was significantly higher, totaling (1,641,051). This indicates that crimes during the evening rush hour are (19.8%) more frequent than those during the morning rush hour, covering the period from 2001 to 2022.
#
# In terms of crime types, a closer look revealed that the most common crime types during both time periods were remarkably similar. The same three crime types topped the list for both the morning and evening rush hours. However, the last two spots on the list showed variation, with different crime types occupying the lower positions during each time frame.

# %% [markdown]
# # Topic 4) Comparing Months:

# %% [markdown]
# ## Answer the question: What months have the most crime? What months have the least?

# %%
monthly_crimes = df.resample('M').size()

monthly_crimes_by_month = monthly_crimes.groupby(monthly_crimes.index.month).sum()
monthly_crimes_by_month
# Out:
# <ipython-input-39-0386ebbea56f>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_crimes = df.resample('M').size()
# Date
# 1     601236
# 2     529391
# 3     629704
# 4     627175
# 5     682932
# 6     681739
# 7     717232
# 8     710444
# 9     668242
# 10    676285
# 11    608961
# 12    579768
# dtype: int64

# %%
most_crime_month = monthly_crimes_by_month.idxmax()
least_crime_month = monthly_crimes_by_month.idxmin()

print(f"Month with the most crimes: {most_crime_month} ({monthly_crimes_by_month.max()} crimes)")
print(f"Month with the least crimes: {least_crime_month} ({monthly_crimes_by_month.min()} crimes)")
# Out:
# Month with the most crimes: 7 (717232 crimes)
# Month with the least crimes: 2 (529391 crimes)

# %%
plt.figure(figsize=(10, 6))
monthly_crimes_by_month.plot(kind='bar', color='skyblue')
plt.title('Total Number of Crimes by Month (2001-2022)', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Total Crimes', fontsize=12)
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Answer the question: Are there any individual crimes that do not follow this pattern? If so, which crimes?

# %%
df['Month'] = df.index.month

overall_monthly_aggregate = df.groupby('Month')['ID'].count()

crime_monthly_aggregate = df.groupby(['Month', 'Primary Type'])['ID'].count().unstack(fill_value=0)

# %%
overall_monthly_aggregate
# Out:
# Month
# 1     601236
# 2     529391
# 3     629704
# 4     627175
# 5     682932
# 6     681739
# 7     717232
# 8     710444
# 9     668242
# 10    676285
# 11    608961
# 12    579768
# Name: ID, dtype: int64

# %%
crime_monthly_aggregate
# Out:
# Primary Type  ARSON  ASSAULT  BATTERY  BURGLARY  \
# Month
# 1               917    34818   101302     32639
# 2               807    33416    93601     25652
# 3              1111    41709   117869     30073
# 4              1097    42031   118500     31372
# 5              1230    48453   135678     36066
# 6              1236    47255   135905     35958
# 7              1350    47900   136817     39279
# 8              1182    46455   128734     40597
# 9              1131    45427   122346     38388
# 10             1118    42925   118812     39550
# 11             1019    36390   102961     37037
# 12              923    34324    98364     35635
#
# Primary Type  CONCEALED CARRY LICENSE VIOLATION  CRIM SEXUAL ASSAULT  \
# Month
# 1                                            62                 2575
# 2                                            69                 1896
# 3                                            77                 2112
# ...

# %%
overall_monthly_diff = overall_monthly_aggregate.diff().dropna()
crime_monthly_diff = crime_monthly_aggregate.diff().dropna()

# %%
overall_monthly_diff
# Out:
# Month
# 2     -71845.0
# 3     100313.0
# 4      -2529.0
# 5      55757.0
# 6      -1193.0
# 7      35493.0
# 8      -6788.0
# 9     -42202.0
# 10      8043.0
# 11    -67324.0
# 12    -29193.0
# Name: ID, dtype: float64

# %%
crime_monthly_diff
# Out:
# Primary Type  ARSON  ASSAULT  BATTERY  BURGLARY  \
# Month
# 2            -110.0  -1402.0  -7701.0   -6987.0
# 3             304.0   8293.0  24268.0    4421.0
# 4             -14.0    322.0    631.0    1299.0
# 5             133.0   6422.0  17178.0    4694.0
# 6               6.0  -1198.0    227.0    -108.0
# 7             114.0    645.0    912.0    3321.0
# 8            -168.0  -1445.0  -8083.0    1318.0
# 9             -51.0  -1028.0  -6388.0   -2209.0
# 10            -13.0  -2502.0  -3534.0    1162.0
# 11            -99.0  -6535.0 -15851.0   -2513.0
# 12            -96.0  -2066.0  -4597.0   -1402.0
#
# Primary Type  CONCEALED CARRY LICENSE VIOLATION  CRIM SEXUAL ASSAULT  \
# Month
# 2                                           7.0               -679.0
# 3                                           8.0                216.0
# 4                                           1.0                 22.0
# 5                                          18.0                270.0
# ...

# %%
opposite_trend_crimes_monthly = []
for crime_type in crime_monthly_diff.columns:
    combined_trend = (overall_monthly_diff * crime_monthly_diff[crime_type]).sum()
    if combined_trend < 0:
        opposite_trend_crimes_monthly.append(crime_type)

# %%
opposite_trend_crimes_monthly
# Out:
# ['NON - CRIMINAL', 'NON-CRIMINAL (SUBJECT SPECIFIED)', 'PUBLIC INDECENCY']

# %%
plt.figure(figsize=(14, 6))
overall_monthly_aggregate.plot(kind='bar', color='blue', alpha=0.7)
plt.title('Overall Monthly Crime Aggregates (2001-2022)')
plt.xlabel('Month')
plt.ylabel('Total Crimes')
plt.xticks(ticks=range(12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(axis='y')
plt.show()

# %%
if opposite_trend_crimes_monthly:
    plt.figure(figsize=(14, 6))
    for crime_type in opposite_trend_crimes_monthly:
        crime_monthly_aggregate[crime_type].plot(label=crime_type, linewidth=1.5)
    plt.title('Crime Types Opposing the Overall Monthly Trend (2001-2022)')
    plt.xlabel('Month')
    plt.ylabel('Total Crimes')
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("No individual crimes have trends opposite to the overall monthly aggregate trend.")

# %% [markdown]
# ## Analysis

# %% [markdown]
# After analyzing the total number of crimes across all months from 2001 to 2022, we observed that crime rates vary significantly throughout the year. The lowest total number of crimes occurred in February, with a combined total of 529,391 crimes over the 22 years. Conversely, the highest number of crimes was recorded in July, with a staggering total of 717,232 crimes during the same period. It is important to note that the number 717,232 represents the cumulative total of crimes that occurred in the month of July across all 22 years.
#
# Next, we investigated specific crime types that exhibited trends contrary to the overall pattern. These crimes showed a decrease during periods when total crimes were generally on the rise. Through this analysis, we identified three types of crimes that behaved differently compared to the overall trend. They are as follows:
#
# ['NON - CRIMINAL', 'NON-CRIMINAL (SUBJECT SPECIFIED)', 'PUBLIC INDECENCY']
#
# This unique insight highlights how certain crimes follow their own distinct patterns, diverging from the general trends observed over the years.

# %% [markdown]
# # core 2 (Forcasting)

# %%
# !pip install pmdarima

# %%
import numpy as np
import seaborn as sns
import os
import statsmodels.tsa.api as tsa
from pmdarima.model_selection import train_test_split
from pmdarima.arima.utils import ndiffs, nsdiffs
# set random seed
SEED = 321
np.random.seed(SEED)
sns.set_context('notebook', font_scale=1.2)
plt.rcParams['figure.figsize']=(12,3)

# %% [markdown]
# ## function section

# %%
def plot_forecast(ts_train, ts_test, forecast_df, n_train_lags=None,
                  figsize=(10,4), title='Comparing Forecast vs. True Data'):
    ### PLot training data, and forecast (with upper/,lower ci)
    fig, ax = plt.subplots(figsize=figsize)
    # setting the number of train lags to plot if not specified
    if n_train_lags==None:
        n_train_lags = len(ts_train)

    # Plotting Training  and test data
    ts_train.iloc[-n_train_lags:].plot(ax=ax, label="train")
    ts_test.plot(label="test", ax=ax)
    # Plot forecast
    forecast_df['mean'].plot(ax=ax, color='green', label="forecast")
    # Add the shaded confidence interval
    ax.fill_between(forecast_df.index,
                    forecast_df['mean_ci_lower'],
                   forecast_df['mean_ci_upper'],
                   color='green', alpha=0.3,  lw=2)
    # set the title and add legend
    ax.set_title(title)
    ax.legend();

    return fig, ax

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

def regression_metrics_ts(ts_true, ts_pred, label="", verbose=True, output_dict=False,):
    # Get metrics
    mae = mean_absolute_error(ts_true, ts_pred)
    mse = mean_squared_error(ts_true, ts_pred)
    # Calculate RMSE manually instead of using squared=False
    rmse = np.sqrt(mse)
    r_squared = r2_score(ts_true, ts_pred)
    mae_perc = mean_absolute_percentage_error(ts_true, ts_pred) * 100
    if verbose == True:
        # Print Result with label
        header = "---" * 20
        print(header, f"Regression Metrics: {label}", header, sep="\n")
        print(f"- MAE = {mae:,.3f}")
        print(f"- MSE = {mse:,.3f}")
        print(f"- RMSE = {rmse:,.3f}")
        print(f"- R^2 = {r_squared:,.3f}")
        print(f"- MAPE = {mae_perc:,.2f}%")
    if output_dict == True:
        metrics = {
            "Label": label,
            "MAE": mae,
            "MSE": mse,
            "RMSE": rmse,
            "R^2": r_squared,
            "MAPE(%)": mae_perc,
        }
        return metrics

# %%
# Custom function for Ad Fuller Test
def get_adfuller_results(ts, alpha=.05, label='adfuller', **kwargs): #kwargs for adfuller()
    # Saving each output
    (test_stat, pval, nlags, nobs, crit_vals_d,
    icbest ) = tsa.adfuller(ts, **kwargs)
    # Converting output to a dictionary with the interpretation of p
    adfuller_results = {'Test Statistic': test_stat,
                        "# of Lags Used":nlags,
                        '# of Observations':nobs,
                        'p-value': round(pval,6),
                        'alpha': alpha,
                       'sig/stationary?': pval < alpha} # Corrected indentation here
    return pd.DataFrame(adfuller_results, index =[label])

# %%
def get_sig_lags(ts, type='ACF',  nlags=None,alpha=0.5):


    if type == 'ACF':
        # Running the function used by plot_acf
        corr_values, conf_int = tsa.stattools.acf(ts, alpha=alpha, nlags=nlags)

    elif type=='PACF':
        corr_values, conf_int = tsa.stattools.pacf(ts, alpha=alpha, nlags=nlags)

    else:
        raise Exception("type must be either 'ACF' or 'PACF'")

    # Determine lags
    lags =range(len(corr_values))

    # Create a centered version of the acf_df
    corr_df = pd.DataFrame({type:corr_values,
                            'Lags':lags,
                            'lower ci': conf_int[:,0]-corr_values, # subtract acf from lower ci to center
                            'upper ci': conf_int[:,1]-corr_values, # subtact acf to upper ci to center
                                 })
    corr_df = corr_df.set_index("Lags")

    # Getting filter for sig lags
    filter_sig_lags = (corr_df[type] < corr_df['lower ci']) | (corr_df[type] > corr_df['upper ci'])

    # Get lag #'s
    sig_lags= corr_df.index[filter_sig_lags]
    sig_lags = sig_lags[sig_lags!=0]

    return sig_lags

# %%
def plot_acf_pacf(ts, nlags=40, figsize=(10, 5),
                  annotate_sig=False, alpha=.05,
                 acf_kws={}, pacf_kws={},
                  annotate_seas=False, m = None,
                 seas_color='black'):

    fig, axes = plt.subplots(nrows=2, figsize=figsize)


    # Sig lags line style
    sig_vline_kwargs = dict( ls=':', lw=1, zorder=0, color='red')

    # ACF
    tsa.graphics.plot_acf(ts, ax=axes[0], lags=nlags, **acf_kws)

    ## Annotating sig acf lags
    if annotate_sig == True:
        sig_acf_lags = get_sig_lags(ts,nlags=nlags,alpha=alpha, type='ACF')
        for lag in sig_acf_lags:
            axes[0].axvline(lag,label='sig', **sig_vline_kwargs )

    # PACF
    tsa.graphics.plot_pacf(ts,ax=axes[1], lags=nlags, **pacf_kws)

    ## Annotating sig pacf lags
    if annotate_sig == True:
        ## ANNOTATING SIG LAGS
        sig_pacf_lags = get_sig_lags(ts,nlags=nlags,alpha=alpha, type='PACF')
        for lag in sig_pacf_lags:
            axes[1].axvline(lag, label='sig', **sig_vline_kwargs)




    ### ANNOTATE SEASONS
    if annotate_seas == True:
        # Ensure m was defined
        if m is None:
            raise Exception("Must define value of m if annotate_seas=True.")

        ## Calculate number of complete seasons to annotate
        n_seasons = nlags//m

        # Seasonal Lines style
        seas_vline_kwargs = dict( ls='--',lw=1, alpha=.7, color=seas_color, zorder=-1)

        ## for each season, add a line
        for i in range(1, n_seasons+1):
            axes[0].axvline(m*i, **seas_vline_kwargs, label="season")
            axes[1].axvline(m*i, **seas_vline_kwargs, label="season")

    fig.tight_layout()

# %% [markdown]
# ## You will compare the crime count forecast for 2 of the options below:

# %% [markdown]
# ### Total Crime (sum of all crime types).

# %%
df
# Out:
#                            ID                Date        Primary Type  \
# Date
# 2001-01-01 01:00:00   1326041 2001-01-01 01:00:00             BATTERY
# 2001-01-01 13:00:00   1319931 2001-01-01 13:00:00             BATTERY
# 2001-01-01 13:00:00   1324743 2001-01-01 13:00:00            GAMBLING
# 2001-01-01 01:00:00   1310717 2001-01-01 01:00:00     CRIMINAL DAMAGE
# 2001-01-01 01:00:00   1318099 2001-01-01 01:00:00             BATTERY
# ...                       ...                 ...                 ...
# 2022-12-31 12:50:00  12938029 2022-12-31 12:50:00             ASSAULT
# 2022-12-31 12:50:00  12937822 2022-12-31 12:50:00             ASSAULT
# 2022-12-31 00:52:00  12937583 2022-12-31 00:52:00             BATTERY
# 2022-12-31 12:52:00  12938420 2022-12-31 12:52:00             ASSAULT
# 2022-12-31 12:59:00  12939906 2022-12-31 12:59:00  DECEPTIVE PRACTICE
#
#                                                  Description  \
# Date
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'Primary Type', 'Description', 'Location Description',
#        'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Latitude',
#        'Longitude', 'Month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7713109 entries, 2001-01-01 01:00:00 to 2022-12-31 12:59:00
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Date                  datetime64[ns]
#  2   Primary Type          object
#  3   Description           object
#  4   Location Description  object
#  5   Arrest                bool
#  6   Domestic              bool
#  7   Beat                  int64
#  8   District              float64
#  9   Ward                  float64
#  10  Latitude              float64
#  11  Longitude             float64
#  12  Month                 int32
# dtypes: bool(2), datetime64[ns](1), float64(4), int32(1), int64(2), object(3)
# memory usage: 691.4+ MB

# %%
monthly_crime_count = df.resample('M').size()

# Display the time series
print(monthly_crime_count)
# Out:
# <ipython-input-62-5480ef1f5439>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_crime_count = df.resample('M').size()
# Date
# 2001-01-31    38119
# 2001-02-28    33787
# 2001-03-31    40566
# 2001-04-30    40091
# 2001-05-31    41839
#               ...
# 2022-08-31    22293
# 2022-09-30    22318
# 2022-10-31    23195
# 2022-11-30    20776
# 2022-12-31    19875
# Freq: ME, Length: 264, dtype: int64

# %%
monthly_crime_count.isna().sum()
# Out:
# 0

# %%
import statsmodels.tsa.api as tsa

# %%
decomp = tsa.seasonal_decompose(monthly_crime_count)
fig = decomp.plot()
fig.set_size_inches(12,5)
fig.tight_layout()

# %%
seasonal = decomp.seasonal
ax = seasonal.loc['2000': '2004'].plot(marker = 'o')

# %%
get_adfuller_results(monthly_crime_count)
# Out:
#           Test Statistic  # of Lags Used  # of Observations   p-value  alpha  \
# adfuller       -1.325784              15                248  0.617295   0.05
#
#           sig/stationary?
# adfuller            False

# %%
# determine d
d = ndiffs(monthly_crime_count)
print (f'd = {d}')
# Out:
# d = 1
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# ...

# %%
# Determine D
D = nsdiffs(monthly_crime_count, m =12)
print(f'D = {D}')
# Out:
# D = 0
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
monthly_crime_count_diff = monthly_crime_count.diff().dropna()

# %%
get_adfuller_results(monthly_crime_count_diff)
# Out:
#           Test Statistic  # of Lags Used  # of Observations   p-value  alpha  \
# adfuller        -3.04041              14                248  0.031289   0.05
#
#           sig/stationary?
# adfuller             True

# %%
plot_acf_pacf(monthly_crime_count_diff,annotate_seas=True, m = 12)

# %%
train, test = train_test_split(monthly_crime_count, test_size=6)
ax = train.plot(label='Train')
test.plot(ax=ax, label='Test')
ax.legend();

# %%
# Orders for non seasonal components
p = 1  # nonseasonal AR
d = 3  # nonseasonal differencing
q = 1  # nonseasonal MA
# Orders for seasonal components
P = 1  # Seasonal AR
D = 0  # Seasonal differencing
Q = 1  # Seasonal MA
m = 12 # Seasonal period
sarima = tsa.ARIMA(train, order = (p,d,q), seasonal_order=(P,D,Q,m)).fit()

# %%
# Obtain summary of forecast as dataframe
forecast_df = sarima.get_forecast(len(test)).summary_frame()
# Plot the forecast with true values
plot_forecast(train, test, forecast_df)
# Obtain metrics
regression_metrics_ts(test, forecast_df["mean"])
# Out:
# ------------------------------------------------------------
# Regression Metrics:
# ------------------------------------------------------------
# - MAE = 755.354
# - MSE = 790,387.189
# - RMSE = 889.037
# - R^2 = 0.362
# - MAPE = 3.42%

# %%
import pmdarima as pm

# Default auto_arima will select model based on AIC score
auto_model = pm.auto_arima(
    train,
    seasonal=True,
    m=12,
    trace=True
)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
print(auto_model.order)
print(auto_model.seasonal_order)
# Out:
# (1, 1, 0)
# (1, 0, 1, 12)

# %%
# Use auto_arima parameters to fit an ARIMA
auto_model = tsa.ARIMA(
    train, order=auto_model.order, seasonal_order=auto_model.seasonal_order
).fit()


# Obtain forecast as a dataframe with confidence intervals
forecast_df = auto_model.get_forecast(steps=len(test)).summary_frame()
# Call the custom function to plot the forecasts with confidence intervals and true values
plot_forecast(train, test, forecast_df);
# Obtain metrics
regression_metrics_ts(test, forecast_df['mean'])
# Out:
# ------------------------------------------------------------
# Regression Metrics:
# ------------------------------------------------------------
# - MAE = 1,572.374
# - MSE = 2,998,538.340
# - RMSE = 1,731.629
# - R^2 = -1.421
# - MAPE = 7.18%

# %%
p = 1  # nonseasonal AR
d = 3  # nonseasonal differencing
q = 1  # nonseasonal MA

# Orders for seasonal components
P = 1  # Seasonal AR
D = 0  # Seasonal differencing
Q = 1  # Seasonal MA
m = 12 # Seasonal period

final_model = tsa.ARIMA(monthly_crime_count, order = (p,d,q), seasonal_order=(P,D,Q,m)).fit()

# %%
len(test)
# Out:
# 6

# %%
forecast_df  = final_model.get_forecast(len(test)).summary_frame()
plot_forecast(train,test,forecast_df);

# %%
forecast_df.index[0],forecast_df.index[-1]
# Out:
# (Timestamp('2023-01-31 00:00:00'), Timestamp('2023-06-30 00:00:00'))

# %%
starting_value = forecast_df['mean'].iloc[0]
starting_value
# Out:
# 18432.639575345926

# %%
final_value = forecast_df['mean'].iloc[-1]
final_value
# Out:
# 15929.59736994723

# %%
change = final_value - starting_value
change
# Out:
# -2503.042205398695

# %%
perc_change = (change / starting_value) * 100
perc_change
# Out:
# -13.579401882010272

# %% [markdown]
# ### Narcotics

# %%
monthly_Narcotics_count = df[df['Primary Type'] == 'NARCOTICS'].resample('M').size()
# Out:
# <ipython-input-87-27b12c24326c>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_Narcotics_count = df[df['Primary Type'] == 'NARCOTICS'].resample('M').size()

# %%
monthly_Narcotics_count
# Out:
# Date
# 2001-01-31    4714
# 2001-02-28    4369
# 2001-03-31    4862
# 2001-04-30    4044
# 2001-05-31    4038
#               ...
# 2022-08-31     420
# 2022-09-30     379
# 2022-10-31     358
# 2022-11-30     339
# 2022-12-31     325
# Freq: ME, Length: 264, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'Primary Type', 'Description', 'Location Description',
#        'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Latitude',
#        'Longitude', 'Month'],
#       dtype='object')

# %%
df['Primary Type'].value_counts()
# Out:
# Primary Type
# THEFT                                1626992
# BATTERY                              1410889
# CRIMINAL DAMAGE                       878914
# NARCOTICS                             746155
# ASSAULT                               501103
# OTHER OFFENSE                         479174
# BURGLARY                              422246
# MOTOR VEHICLE THEFT                   366586
# DECEPTIVE PRACTICE                    340958
# ROBBERY                               289677
# CRIMINAL TRESPASS                     212869
# WEAPONS VIOLATION                     103906
# PROSTITUTION                           69750
# OFFENSE INVOLVING CHILDREN             55280
# PUBLIC PEACE VIOLATION                 52086
# SEX OFFENSE                            30442
# CRIM SEXUAL ASSAULT                    27584
# INTERFERENCE WITH PUBLIC OFFICER       18206
# LIQUOR LAW VIOLATION                   14846
# GAMBLING                               14616
# ...

# %%
monthly_Narcotics_count.isna().sum()
# Out:
# 0

# %%
decomp_2 = tsa.seasonal_decompose(monthly_Narcotics_count)
fig = decomp.plot()
fig.set_size_inches(12,5)
fig.tight_layout()

# %%
get_adfuller_results(monthly_Narcotics_count)
# Out:
#           Test Statistic  # of Lags Used  # of Observations   p-value  alpha  \
# adfuller        0.265472              12                251  0.975704   0.05
#
#           sig/stationary?
# adfuller            False

# %%
# determine d
d = ndiffs(monthly_Narcotics_count)
print (f'd = {d}')
# Out:
# d = 1
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# ...

# %%
# Determine D
D = nsdiffs(monthly_Narcotics_count, m =12)
print(f'D = {D}')
# Out:
# D = 0
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
monthly_Narcotics_count_diff=monthly_Narcotics_count.diff().dropna()

# %%
get_adfuller_results(monthly_Narcotics_count_diff)
# Out:
#           Test Statistic  # of Lags Used  # of Observations   p-value  alpha  \
# adfuller       -5.393766              11                251  0.000003   0.05
#
#           sig/stationary?
# adfuller             True

# %%
plot_acf_pacf(monthly_Narcotics_count_diff,annotate_seas=True, m = 12)

# %%
train, test = train_test_split(monthly_Narcotics_count, test_size=6)
ax = train.plot(label='Train')
test.plot(ax=ax, label='Test')
ax.legend();

# %%
# Orders for non seasonal components
p = 1  # nonseasonal AR
d = 1  # nonseasonal differencing
q = 1  # nonseasonal MA
# Orders for seasonal components
P = 1  # Seasonal AR
D = 0  # Seasonal differencing
Q = 1  # Seasonal MA
m = 12 # Seasonal period
sarima = tsa.ARIMA(train, order = (p,d,q), seasonal_order=(P,D,Q,m)).fit()

# %%
# Obtain summary of forecast as dataframe
forecast_df = sarima.get_forecast(len(test)).summary_frame()
# Plot the forecast with true values
plot_forecast(train, test, forecast_df)
# Obtain metrics
regression_metrics_ts(test, forecast_df["mean"])
# Out:
# ------------------------------------------------------------
# Regression Metrics:
# ------------------------------------------------------------
# - MAE = 73.857
# - MSE = 7,168.465
# - RMSE = 84.667
# - R^2 = -6.721
# - MAPE = 21.14%

# %%
import pmdarima as pm

# Default auto_arima will select model based on AIC score
auto_model = pm.auto_arima(
    train,
    seasonal=True,
    m=12,
    trace=True
)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
print(auto_model.order)
print(auto_model.seasonal_order)
# Out:
# (4, 1, 0)
# (1, 0, 1, 12)

# %%
# Use auto_arima parameters to fit an ARIMA
auto_model = tsa.ARIMA(
    train, order=auto_model.order, seasonal_order=auto_model.seasonal_order
).fit()


# Obtain forecast as a dataframe with confidence intervals
forecast_df = auto_model.get_forecast(steps=len(test)).summary_frame()
# Call the custom function to plot the forecasts with confidence intervals and true values
plot_forecast(train, test, forecast_df);
# Obtain metrics
regression_metrics_ts(test, forecast_df['mean'])
# Out:
# ------------------------------------------------------------
# Regression Metrics:
# ------------------------------------------------------------
# - MAE = 34.565
# - MSE = 1,829.463
# - RMSE = 42.772
# - R^2 = -0.970
# - MAPE = 9.88%

# %%
# These are the parameters of our final model
# Orders for non seasonal components
p = 4  # nonseasonal AR
d = 1  # nonseasonal differencing
q = 0  # nonseasonal MA

# Orders for seasonal components
P = 1  # Seasonal AR
D = 0  # Seasonal differencing
Q = 1  # Seasonal MA
m = 12 # Seasonal period

final_model = tsa.ARIMA(monthly_Narcotics_count, order = (p,d,q), seasonal_order=(P,D,Q,m)).fit()

# %%
len(test)
# Out:
# 6

# %%
# Obtain future forecasts beyond test data
forecast_df  = final_model.get_forecast(len(test)).summary_frame()
plot_forecast(train,test,forecast_df);

# %%
forecast_df.index[0],forecast_df.index[-1]
# Out:
# (Timestamp('2023-01-31 00:00:00'), Timestamp('2023-06-30 00:00:00'))

# %%
starting_value = forecast_df['mean'].iloc[0]
starting_value
# Out:
# 412.1735282293731

# %%
final_value = forecast_df['mean'].iloc[-1]
final_value
# Out:
# 283.81032981967905

# %%
change = final_value - starting_value
change
# Out:
# -128.36319840969406

# %%
perc_change = (change / starting_value) * 100
perc_change
# Out:
# -31.14299915405057

# %% [markdown]
# ## Which of the two crimes is forecasted to have the highest monthly count of crimes at the end of the forecast?

# %% [markdown]
# ### Total crime with 15,929.60 crime

# %% [markdown]
# ## Which of the two crimes is forecasted to have the highest net change by the end of the forecast?

# %% [markdown]
# ### The absolute value of the change is higher for total crime.

# %% [markdown]
# ### Which of the two crimes is forecasted to have the highest percent change by the end of the forecast?

# %% [markdown]
# ### Narcotics, as it has the higher percentage change with 31.14%
